# %%
import pandas as pd

# %%
data=pd.read_csv("abalone.csv")

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.sort_values("Length",axis=0)  #this is for the sort the values in the data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1986   I   0.135     0.130   0.040        0.0290          0.0125
# ...   ..     ...       ...     ...           ...             ...
# 2090   M   0.775     0.570   0.220        2.0320          0.7350
# 3715   M   0.780     0.600   0.210        2.5480          1.1945
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
#
#       Viscera weight  Shell weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# ...

# %%
from sklearn.preprocessing import LabelEncoder
k=LabelEncoder()
data.Sex=k.fit_transform(data.Sex)

# %%
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
0.365	0.095	0.5140	0.2245	0.1010	0.1500	15

# %%
data.length1=0.455
data.diameter1=0.095
data.height1=0.5140
data.weight1=
