# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x1=np.array(data.Pregnancies)
x2=np.array(data.Glucose)
x3=np.array(data.BloodPressure)
x4=np.array(data.SkinThickness)
x5=np.array(data.Insulin)
x6=np.array(data.BMI)
x7=np.array(data.DiabetesPedigreeFunction)
x8=np.array(data.Age)
target=np.array(data.Outcome)

# %%
data.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
x1=x1/17
x2=x2/199
x3=x3/122
x4=x4/99
x5=x5/846
x6=x6/67
x7=x7/2.42
x8=x8/81

# %%
import random
w0=random.random()
w1=random.random()
w2=random.random()
w3=random.random()
w4=random.random()
w5=random.random()
w6=random.random()
w7=random.random()
w8=random.random()

# %%
y=w0+w1*x1+w2*x2+w3*x3+w4*x4+w5*x5+w6*x6+w7*x7*w8*x8

# %%
y
# Out:
# array([1.86394088, 1.4776653 , 1.50390559, 1.49230542, 1.68155385,
#        1.39977254, 1.54168801, 1.17843141, 2.18327323, 1.40227979,
#        1.57603826, 1.72381996, 1.63433169, 2.05029534, 1.74428865,
#        1.03068162, 2.07355194, 1.47626103, 1.56622398, 1.6807274 ,
#        2.08097526, 1.60437443, 1.79478235, 1.90484998, 2.20945394,
#        1.88096052, 1.63394739, 1.41405632, 1.918482  , 1.58432905,
#        1.73443154, 1.94941214, 1.33472674, 1.44838708, 1.87821093,
#        1.67719585, 1.67566839, 1.91353707, 1.74757245, 2.02382999,
#        1.72691508, 1.67092495, 1.6897937 , 2.34349854, 1.47517863,
#        1.82686639, 1.26649734, 1.50198832, 1.80482755, 0.7732216 ,
#        1.40294011, 1.27550678, 1.50975924, 2.22663983, 2.12585441,
#        1.1549123 , 2.16529573, 2.13561741, 1.50169936, 1.78929955,
#        0.60614671, 1.55947918, 1.2197647 , 1.64952797, 1.46769869,
#        1.65613287, 1.68247884, 1.57328277, 1.3028695 , 1.81916214,
# ...

# %%
yp=1/(1+np.exp(-y))

# %%
yp
# Out:
# array([0.86575563, 0.81421968, 0.81815626, 0.81642405, 0.84311018,
#        0.80214779, 0.82370998, 0.76466565, 0.89873735, 0.80254541,
#        0.82864271, 0.84862022, 0.83676217, 0.88597746, 0.85123098,
#        0.73704802, 0.88830587, 0.81400717, 0.82724464, 0.84300083,
#        0.88904028, 0.83262888, 0.85751261, 0.87043946, 0.90109527,
#        0.86772141, 0.83670967, 0.80440494, 0.87196906, 0.82981674,
#        0.84997839, 0.87538253, 0.79162142, 0.80975008, 0.86740549,
#        0.84253286, 0.8423301 , 0.871416  , 0.85164635, 0.88327646,
#        0.8490174 , 0.8416991 , 0.84419703, 0.91241607, 0.81384324,
#        0.861388  , 0.78014256, 0.81787084, 0.85873557, 0.68421738,
#        0.80265003, 0.78168396, 0.81902552, 0.9026164 , 0.89339081,
#        0.76040702, 0.89708948, 0.89431711, 0.81782779, 0.85684138,
#        0.64706131, 0.82627861, 0.77202214, 0.83882724, 0.81270735,
#        0.8397182 , 0.84323249, 0.82825109, 0.78631752, 0.86046556,
# ...

# %%
loss=-1*sum((target*np.log(yp)+((1-target)*np.log(1-yp))))

# %%
loss
# Out:
# 928.454637350633

# %%
w0=random.random()
w1=random.random()
w2=random.random()
w3=random.random()
w4=random.random()
w5=random.random()
w6=random.random()
w7=random.random()
w8=random.random()
k=0
lr=.001
while(k<1000):
    k=k+1
    y=w0+w1*x1+w2*x2+w3*x3+w4*x4+w5*x5+w6*x6+w7*x7*w8*x8
    yp=1/(1+np.exp(-y))
    loss=-1*sum((target*np.log(yp)+((1-target)*np.log(1-yp))))
    print(loss)
    w0=w0-lr*sum(yp-target)
    w1=w1-lr*sum((yp-target)*x1)
    w2=w2-lr*sum((yp-target)*x2)
    w3=w3-lr*sum((yp-target)*x3)
    w4=w4-lr*sum((yp-target)*x4)
    w5=w5-lr*sum((yp-target)*x5)
    w6=w6-lr*sum((yp-target)*x6)
    w7=w7-lr*sum((yp-target)*x7)
    w8=w8-lr*sum((yp-target)*x8)
# Out:
# 845.9294392628992
# 650.5805979411743
# 558.7745702359431
# 522.6143059070838
# 508.83734962499983
# 503.24351218034604
# 500.6363304686992
# 499.1435726050645
# 498.0767772204688
# 497.17708773796437
# 496.3455959222311
# 495.5441553053057
# 494.75800339471084
# 493.98143535904035
# 493.21225652599946
# 492.449624516858
# 491.6932105000607
# 490.9428753140861
# 490.1985462179266
# 489.46017127796256
# 488.72770336679184
# 488.00109515622444
# 487.28029798857324
# 486.5652619764428
# 485.8559363913612
# 485.15227004017265
# 484.4542115557115
# 483.76170960196123
# 483.0747130124838
# 482.39317088152455
# 481.717032623037
# 481.04624800853077
# 480.3807671911048
# 479.7205407205575
# 479.06551955273954
# 478.41565505518815
# 477.770899010358
# 477.1312036172923
# 476.49652149225903
# 475.866805668702
# 475.2420095967207
# 474.6220871422158
# 474.0069925858007
# 473.3966806215222
# 472.79110635544566
# 472.1902253041128
# 471.5939933929077
# 471.0023669543165
# 470.41530272612613
# ...

# %%
print(w0,w1,w2,w3,w4,w5,w6,w7,w8)
# Out:
# -5.950017208936464 1.9810263426952555 5.694408239683452 -1.2966388962869546 0.12996706889299817 -0.08943439611929495 3.4167417340392654 2.726853157664098 1.6178291585278346

# %%
data.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
